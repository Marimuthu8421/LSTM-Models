# %% [markdown]
# ## Step 0: Pre-Requirements - Import Modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib
from statsmodels.tools.eval_measures import rmse 
from sklearn.preprocessing import MinMaxScaler
import keras
import tensorflow as tf
from keras.preprocessing.sequence import TimeseriesGenerator
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
import warnings 
warnings.filterwarnings("ignore")
# Out:
# Using matplotlib backend: agg
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ## Step 1 : Import data set and draw ACF / PACF plot then choose time lag

# %% [markdown]
# Run the below code and click 'Choose Files' then browse your data (.csv file).

# %%
from google.colab import files
uploaded = files.upload()

# %% [markdown]
# Import the uploaded data as name 'df' using the function pd.read_csv()

# %%
import pandas as pd
import io
df = pd.read_csv(io.BytesIO(uploaded['UK covid19 train_data.csv']))

# Print variable names
print(list(df.columns))

# Print Head of the data
print(df.head())

# %%
# Month  is already in index of df otherwise change it usingthe following code
# change the Month column as Index

df1=df
df1.Date=pd.to_datetime(df.Date)
df1=df1.set_index("Date")
df1.head()
# Out:
#             Days  Confirmed  Cumulative_cases
# Date
# 2021-05-01     1       2381           4416627
# 2021-05-02     2       1907           4418534
# 2021-05-03     3       1671           4420205
# 2021-05-04     4       1649           4421854
# 2021-05-05     5       1946           4423800

# %% [markdown]
# Plot line graph for Daily cases using the code given below

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(9, 7))
ax.plot(df1.index.values, df1['Confirmed'])
ax.set(xlabel="Date",
       ylabel="Cofirmed cases per day",
       title="Covid19 Cases")

plt.show()

# %% [markdown]
# Draw ACF / PACF plot using the function accf() / pacf(). Choose the significant lag as the optimal time step which can be used for data pre-processing.

# %%
## Auto correlation and Partial Auto correlation Plot
from statsmodels.graphics.tsaplots import acf, pacf, plot_pacf, plot_acf
from matplotlib import pyplot

import numpy as np
dat=np.array(df1['Confirmed'])

plot_acf(dat)
plot_pacf(dat)
pyplot.show()

# %% [markdown]
# ## Step2: Data pre-processing

# %% [markdown]
# We can divide the sequence into input (X) and output (y).
# Let {Xi, i=1, 2, 3, …, n} be the daily incident cases. Suppose, lag is three, then the fourth day count depends on previous 3 days (third, second and first) and fifth day count depends on fourth, third, and second day counts, and so on. Therefore, the data should be organized as follows:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Define the function **prepare_data()** which convert the time series data into X and y.

# %%
# preparing independent and dependent features
def split_sequence(sequence, n_step):
	X, y = list(), list()
	for i in range(len(sequence)):
		# find the end of this pattern
		end_ix = i + n_step
		# check if we are beyond the sequence
		if end_ix > len(sequence)-1:
			break
		# gather input and output parts of the pattern
		seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
		X.append(seq_x)
		y.append(seq_y)
	return np.array(X), np.array(y)

# %%
n_step=14 # Choose from the ACF plot

# split into samples
X, y = split_sequence(df['Confirmed'], n_step)

print(X.shape)

# %%
# Summarize the data
for i in range(len(X)):
  print(X[i], y[i])
# Out:
# [2381 1907 1671 1649 1946 2144 2613 2490 2047 1770 2357 2474 2284 2656] 2193
# [1907 1671 1649 1946 2144 2613 2490 2047 1770 2357 2474 2284 2656 2193] 2027
# [1671 1649 1946 2144 2613 2490 2047 1770 2357 2474 2284 2656 2193 2027] 1926
# [1649 1946 2144 2613 2490 2047 1770 2357 2474 2284 2656 2193 2027 1926] 1979
# [1946 2144 2613 2490 2047 1770 2357 2474 2284 2656 2193 2027 1926 1979] -2364
# [ 2144  2613  2490  2047  1770  2357  2474  2284  2656  2193  2027  1926
#   1979 -2364] 2135
# [ 2613  2490  2047  1770  2357  2474  2284  2656  2193  2027  1926  1979
#  -2364  2135] 2694
# [ 2490  2047  1770  2357  2474  2284  2656  2193  2027  1926  1979 -2364
#   2135  2694] 2702
# %%
# reshape from [samples, timesteps] into [samples, timesteps, features]
n_features = 1
n_seq=7
n_steps=2
X = X.reshape((X.shape[0],  n_seq, n_steps, n_features))
print(X.shape)
#print(X)
# Out:
# (248, 7, 2, 1)

# %% [markdown]
# ## Step 4: Model Buiilding

# %% [markdown]
# A CNN model can be used in a hybrid model with an LSTM backend where the CNN is used to interpret subsequences of input that together are provided as a sequence to an LSTM model to interpret. This hybrid model is called a CNN-LSTM.
#
# Our CNN-LSTM model has one 1d-CNN layer followed by max-pooling layer and flatten layer.  Then two LSTM layers with 500 neurons followed by eight dense layers
#
# However, the dense layers can be adjusted based on the model perfomance.

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten, TimeDistributed
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D

# define model
model = Sequential()
model.add(TimeDistributed(Conv1D(filters=64, kernel_size=1, activation='relu',kernel_initializer='he_uniform',kernel_regularizer =keras.regularizers.l2( l=0.01)), input_shape=(None, n_steps, n_features)))
model.add(TimeDistributed(MaxPooling1D(pool_size=2)))
model.add(TimeDistributed(Flatten()))

#model.add(TimeDistributed(Conv1D(filters=64, kernel_size=1, activation='relu',kernel_initializer='he_uniform',kernel_regularizer =keras.regularizers.l2( l=0.01))))
#model.add(TimeDistributed(MaxPooling1D(pool_size=1)))
#model.add(TimeDistributed(Flatten()))

model.add(LSTM(500, activation='relu',return_sequences=True,kernel_initializer='he_uniform',kernel_regularizer =keras.regularizers.l2( l=0.01)))
model.add(LSTM(500, activation='relu',kernel_initializer='he_uniform',kernel_regularizer =keras.regularizers.l2( l=0.01)))
#model.add(Dropout(0.3))))
#model.add(Dropout(0.3))


#model.add(Dense(5000, activation='relu',kernel_initializer='he_uniform',kernel_regularizer =keras.regularizers.l2( l=0.01)))
#model.add(Dense(3000, activation='relu',kernel_initializer='he_uniform',kernel_regularizer =keras.regularizers.l2( l=0.01)))
#model.add(Dense(2000, activation='relu',kernel_initializer='he_uniform',kernel_regularizer =keras.regularizers.l2( l=0.01)))
model.add(Dense(1000, activation='relu',kernel_initializer='he_uniform',kernel_regularizer =keras.regularizers.l2( l=0.01)))
model.add(Dense(500, activation='relu',kernel_initializer='he_uniform',kernel_regularizer =keras.regularizers.l2( l=0.01)))
model.add(Dense(300, activation='relu',kernel_initializer='he_uniform',kernel_regularizer =keras.regularizers.l2( l=0.01)))
model.add(Dense(200, activation='relu',kernel_initializer='he_uniform',kernel_regularizer =keras.regularizers.l2( l=0.01)))
model.add(Dense(100, activation='relu',kernel_initializer='he_uniform',kernel_regularizer =keras.regularizers.l2( l=0.01)))
model.add(Dense(1))

# %%
# Compile the Model
model.compile(optimizer='adam', loss='mse')

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed_6 (TimeDis  (None, None, 2, 64)      128
#  tributed)
#
#  time_distributed_7 (TimeDis  (None, None, 1, 64)      0
#  tributed)
#
#  time_distributed_8 (TimeDis  (None, None, 64)         0
#  tributed)
#
#  lstm_4 (LSTM)               (None, None, 500)         1130000
#
#  lstm_5 (LSTM)               (None, 500)               2002000
#
#  dense_18 (Dense)            (None, 1000)              501000
#
#  dense_19 (Dense)            (None, 500)               500500
#
#  dense_20 (Dense)            (None, 300)               150300
#
#  dense_21 (Dense)            (None, 200)               60200
#
#  dense_22 (Dense)            (None, 100)               20100
#
#  dense_23 (Dense)            (None, 1)                 101
#
# =================================================================
# Total params: 4,364,329
# Trainable params: 4,364,329
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Call backs**
#
# **reuce lr (Learning Rate)**-if no  improvement seeing for the patience the learning rate is reuce.
#
# **factor** - by which the learning eate will be reduce.
#
# **patience** - # of epochs with no improvement after that the learning rate will reduce
#
# **verbose** - contain binary 0 quit 1 update message.
#
# **mode** - auto min max,
#     **min** - LR will reduce when quantity
# monitor has stop decresing;
#     **max** -  LR will reduce when quantity monitor has stop incresing;
#     **auto** - the direction is automatically infere from the nameof monitor.

# %%
# Call backs
# reuce lr (Learning Rate)-if no  improvement seeing for the patience the learning rate is reuce
# factor - by which the learning eate will be reduce
# patience - # of epochs with no improvement after that the learning rate will reduce
# verbose - contain binary 0 quit 1 update msg
# mode - auto min max, min - LR will reduce when quantity monitor has stop decresing
#         max -  LR will reduce when quantity monitor has stop incresing
#         auto - the direction is automatically infere from the nameof monitor
# Early stopping  

from keras.callbacks import ModelCheckpoint
from keras.callbacks import ReduceLROnPlateau
from keras.callbacks import EarlyStopping

checkpoint=ModelCheckpoint(filepath='best_weights.hdf11', 
                           save_best_only=True, save_weights_only=True)
lr_reduce=ReduceLROnPlateau(monitor='loss',factor=0.3,
                            patience=3,  verbose=2, mode='max')
early_stop=EarlyStopping(monitor='loss',min_delta=0.1, patience=3, mode='min')

# %% [markdown]
# ## Step 5: Fitting and evaluating the model
#
# Fit a model using the train data and evaluate the performance. The Mean Squared Error (MSE) / Mean Absolute Error (MAE) can be used as the metrics to evaluate model performance of both train and test data.

# %%
# fit model

model.fit(X, y, epochs=100,batch_size=32, verbose=1,callbacks=[checkpoint,lr_reduce])
# Out:
# Epoch 1/100
# 8/8 [==============================] - ETA: 0s - loss: 107482275840.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/8 [==============================] - 4s 185ms/step - loss: 107482275840.0000 - lr: 0.0010
# Epoch 2/100
# 8/8 [==============================] - ETA: 0s - loss: 2535363584.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/8 [==============================] - 1s 185ms/step - loss: 2535363584.0000 - lr: 0.0010
# Epoch 3/100
# 8/8 [==============================] - ETA: 0s - loss: 1117548672.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/8 [==============================] - 1s 176ms/step - loss: 1117548672.0000 - lr: 0.0010
# Epoch 4/100
# 8/8 [==============================] - ETA: 0s - loss: 1210281984.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 8/8 [==============================] - 1s 174ms/step - loss: 1210281984.0000 - lr: 0.0010
# Epoch 5/100
# 8/8 [==============================] - ETA: 0s - loss: 658534592.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/8 [==============================] - 1s 174ms/step - loss: 658534592.0000 - lr: 3.0000e-04
# Epoch 6/100
# 8/8 [==============================] - ETA: 0s - loss: 287807904.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/8 [==============================] - 1s 177ms/step - loss: 287807904.0000 - lr: 3.0000e-04
# Epoch 7/100
# 8/8 [==============================] - ETA: 0s - loss: 166161824.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 8/8 [==============================] - 1s 177ms/step - loss: 166161824.0000 - lr: 3.0000e-04
# Epoch 8/100
# 8/8 [==============================] - ETA: 0s - loss: 279074048.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/8 [==============================] - 1s 175ms/step - loss: 279074048.0000 - lr: 9.0000e-05
# Epoch 9/100
# 8/8 [==============================] - ETA: 0s - loss: 271575680.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/8 [==============================] - 1s 174ms/step - loss: 271575680.0000 - lr: 9.0000e-05
# Epoch 10/100
# 8/8 [==============================] - ETA: 0s - loss: 206531424.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 8/8 [==============================] - 1s 175ms/step - loss: 206531424.0000 - lr: 9.0000e-05
# Epoch 11/100
# 8/8 [==============================] - ETA: 0s - loss: 125091544.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/8 [==============================] - 1s 177ms/step - loss: 125091544.0000 - lr: 2.7000e-05
# Epoch 12/100
# 8/8 [==============================] - ETA: 0s - loss: 137264272.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/8 [==============================] - 1s 179ms/step - loss: 137264272.0000 - lr: 2.7000e-05
# Epoch 13/100
# 8/8 [==============================] - ETA: 0s - loss: 143743424.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
# 8/8 [==============================] - 1s 173ms/step - loss: 143743424.0000 - lr: 2.7000e-05
# Epoch 14/100
# 8/8 [==============================] - ETA: 0s - loss: 133255392.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/8 [==============================] - 1s 172ms/step - loss: 133255392.0000 - lr: 8.1000e-06
# Epoch 15/100
# 8/8 [==============================] - ETA: 0s - loss: 122446000.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/8 [==============================] - 1s 174ms/step - loss: 122446000.0000 - lr: 8.1000e-06
# Epoch 16/100
# 8/8 [==============================] - ETA: 0s - loss: 119004376.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-06.
# 8/8 [==============================] - 1s 172ms/step - loss: 119004376.0000 - lr: 8.1000e-06
# Epoch 17/100
# 8/8 [==============================] - ETA: 0s - loss: 116699096.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/8 [==============================] - 1s 168ms/step - loss: 116699096.0000 - lr: 2.4300e-06
# Epoch 18/100
# 8/8 [==============================] - ETA: 0s - loss: 115358864.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/8 [==============================] - 1s 168ms/step - loss: 115358864.0000 - lr: 2.4300e-06
# Epoch 19/100
# 8/8 [==============================] - ETA: 0s - loss: 115482888.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 7.289999985005124e-07.
# 8/8 [==============================] - 1s 172ms/step - loss: 115482888.0000 - lr: 2.4300e-06
# Epoch 20/100
# 8/8 [==============================] - ETA: 0s - loss: 115645624.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/8 [==============================] - 1s 172ms/step - loss: 115645624.0000 - lr: 7.2900e-07
# Epoch 21/100
# 8/8 [==============================] - ETA: 0s - loss: 115185888.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/8 [==============================] - 1s 170ms/step - loss: 115185888.0000 - lr: 7.2900e-07
# Epoch 22/100
# 8/8 [==============================] - ETA: 0s - loss: 114901736.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 2.1870000637136398e-07.
# 8/8 [==============================] - 1s 171ms/step - loss: 114901736.0000 - lr: 7.2900e-07
# Epoch 23/100
# 8/8 [==============================] - ETA: 0s - loss: 114327512.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/8 [==============================] - 1s 168ms/step - loss: 114327512.0000 - lr: 2.1870e-07
# Epoch 24/100
# 8/8 [==============================] - ETA: 0s - loss: 114243600.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/8 [==============================] - 1s 167ms/step - loss: 114243600.0000 - lr: 2.1870e-07
# Epoch 25/100
# 8/8 [==============================] - ETA: 0s - loss: 114138872.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 6.561000276406048e-08.
# 8/8 [==============================] - 1s 168ms/step - loss: 114138872.0000 - lr: 2.1870e-07
# Epoch 26/100
# 8/8 [==============================] - ETA: 0s - loss: 114062024.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/8 [==============================] - 1s 170ms/step - loss: 114062024.0000 - lr: 6.5610e-08
# Epoch 27/100
# 8/8 [==============================] - ETA: 0s - loss: 114037184.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/8 [==============================] - 1s 170ms/step - loss: 114037184.0000 - lr: 6.5610e-08
# Epoch 28/100
# 8/8 [==============================] - ETA: 0s - loss: 114009544.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 1.9683000829218145e-08.
# 8/8 [==============================] - 1s 170ms/step - loss: 114009544.0000 - lr: 6.5610e-08
# Epoch 29/100
# 8/8 [==============================] - ETA: 0s - loss: 113986544.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/8 [==============================] - 1s 168ms/step - loss: 113986544.0000 - lr: 1.9683e-08
# Epoch 30/100
# 8/8 [==============================] - ETA: 0s - loss: 113979592.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/8 [==============================] - 1s 173ms/step - loss: 113979592.0000 - lr: 1.9683e-08
# Epoch 31/100
# 8/8 [==============================] - ETA: 0s - loss: 113972848.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 5.904900035602622e-09.
# 8/8 [==============================] - 1s 172ms/step - loss: 113972848.0000 - lr: 1.9683e-08
# Epoch 32/100
# 8/8 [==============================] - ETA: 0s - loss: 113966288.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/8 [==============================] - 1s 167ms/step - loss: 
0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/8 [==============================] - 1s 169ms/step - loss: 113963056.0000 - lr: 2.0589e-19
# Epoch 93/100
# 8/8 [==============================] - ETA: 0s - loss: 113962944.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/8 [==============================] - 1s 170ms/step - loss: 113962944.0000 - lr: 2.0589e-19
# Epoch 94/100
# 8/8 [==============================] - ETA: 0s - loss: 113962928.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#
# Epoch 00094: ReduceLROnPlateau reducing learning rate to 6.176734056048479e-20.
# 8/8 [==============================] - 1s 169ms/step - loss: 113962928.0000 - lr: 2.0589e-19
# Epoch 95/100
# 8/8 [==============================] - ETA: 0s - loss: 113962920.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/8 [==============================] - 1s 170ms/step - loss: 113962920.0000 - lr: 6.1767e-20
# Epoch 96/100
# 8/8 [==============================] - ETA: 0s - loss: 113962936.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/8 [==============================] - 1s 169ms/step - loss: 113962936.0000 - lr: 6.1767e-20
# Epoch 97/100
# 8/8 [==============================] - ETA: 0s - loss: 113963016.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#
# Epoch 00097: ReduceLROnPlateau reducing learning rate to 1.8530202168145436e-20.
# 8/8 [==============================] - 1s 171ms/step - loss: 113963016.0000 - lr: 6.1767e-20
# Epoch 98/100
# 8/8 [==============================] - ETA: 0s - loss: 113962968.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/8 [==============================] - 1s 169ms/step - loss: 113962968.0000 - lr: 1.8530e-20
# Epoch 99/100
# 8/8 [==============================] - ETA: 0s - loss: 113962984.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/8 [==============================] - 1s 168ms/step - loss: 113962984.0000 - lr: 1.8530e-20
# Epoch 100/100
# 8/8 [==============================] - ETA: 0s - loss: 113963080.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#
# Epoch 00100: ReduceLROnPlateau reducing learning rate to 5.559060844314087e-21.
# 8/8 [==============================] - 1s 174ms/step - loss: 113963080.0000 - lr: 1.8530e-20

# %%
# Predict the data for training data set.

y_hat=model.predict(X, verbose=1)
print(y_hat)
# Out:
# 8/8 [==============================] - 1s 44ms/step
# [[  2248.331 ]
#  [  2173.6682]
#  [  2240.064 ]
#  [  2072.6653]
#  [  2012.0624]
#  [  1463.2019]
#  [  1225.7349]
#  [  2756.4778]
#  [  1680.5253]
#  [  2142.54  ]
#  [  2110.1882]
#  [  1920.5366]
#  [  1854.763 ]
#  [  2374.4531]
#  [  3259.6782]
#  [  2532.5305]
#  [  2815.8494]
#  [  2777.173 ]
#  [  2735.213 ]
#  [  3266.7244]
#  [  3559.3982]
#  [  4948.672 ]
#  [  5019.53  ]
#  [  5221.744 ]
#  [  4825.1523]
#  [  5678.6514]
#  [  5259.906 ]
#  [  6097.0537]
#  [  7093.9033]
#  [  7739.045 ]
#  [  8181.4697]
#  [  7469.9814]
#  [  7852.121 ]
#  [  6965.258 ]
#  [  7422.5645]
#  [  7987.1167]
#  [ 11839.494 ]
#  [  9882.438 ]
#  [ 10390.995 ]
#  [ 10377.36  ]
#  [ 10363.312 ]
#  [ 14292.634 ]
#  [ 14262.814 ]
#  [ 14935.486 ]
#  [ 16362.412 ]
#  [ 19880.459 ]
#  [ 21877.307 ]
#  [ 19458.324 ]
#  [ 20719.844 ]
#  [ 23053.623 ]
#  [ 24962.709 ]
#  [ 28047.105 ]
#  [ 26445.348 ]
#  [ 24347.408 ]
#  [ 25283.744 ]
#  [ 27370.416 ]
#  [ 24878.69  ]
#  [ 31864.176 ]
#  [ 31068.63  ]
#  [ 33377.97  ]
#  [ 33870.03  ]
#  [ 29240.34  ]
#  [ 32513.877 ]
#  [ 35645.113 ]
#  [ 52131.125 ]
#  [ 57543.895 ]
#  [ 54346.117 ]
#  [ 46982.56  ]
#  [ 49300.125 ]
#  [ 52547.52  ]
#  [ 49676.965 ]
#  [ 46083.277 ]
#  [ 20397.578 ]
#  [ 24160.61  ]
#  [ 37032.508 ]
#  [ 22119.256 ]
#  [ 16704.227 ]
#  [ 21579.682 ]
#  [ 15303.227 ]
#  [ 29890.635 ]
#  [ 26975.861 ]
#  [ 16276.328 ]
#  [ 15297.804 ]
#  [ 23827.87  ]
#  [ 24239.924 ]
#  [ 26772.035 ]
#  [ 26542.33  ]
#  [ 27827.527 ]
#  [ 26661.32  ]
#  [ 25614.742 ]
#  [ 34236.12  ]
#  [ 26619.375 ]
#  [ 30401.793 ]
#  [ 31002.742 ]
#  [ 32892.08  ]
#  [ 28379.168 ]
#  [ 33871.51  ]
#  [ 29087.094 ]
#  [ 30285.625 ]
#  [ 30327.98  ]
#  [ 31280.57  ]
#  [ 38111.645 ]
#  [ 41433.945 ]
#  [ 29247.367 ]
#  [ 31930.639 ]
#  [ 31690.797 ]
#  [ 37878.062 ]
#  [ 32115.326 ]
#  [ 40328.566 ]
#  [ 41535.164 ]
#  [ 37703.445 ]
#  [ 37778.215 ]
#  [ 34334.754 ]
#  [ 31498.807 ]
#  [ 31795.887 ]
#  [ 37106.957 ]
#  [ 37030.57  ]
#  [ 46382.41  ]
#  [ 36355.984 ]
#  [ 37082.625 ]
#  [ 36819.53  ]
#  [ 37979.43  ]
#  [ 31113.771 ]
#  [ 20306.627 ]
#  [ 29354.389 ]
#  [ 31103.598 ]
#  [ 27450.617 ]
#  [ 29496.37  ]
#  [ 29626.186 ]
#  [ 32673.297 ]
#  [ 28870.59  ]
#  [ 30919.027 ]
#  [ 27610.4   ]
#  [ 25863.547 ]
#  [ 40378.438 ]
#  [ 41900.918 ]
#  [ 33803.695 ]
#  [ 36220.105 ]
#  [ 38797.6   ]
#  [ 35668.98  ]
#  [ 35948.227 ]
#  [ 36170.34  ]
#  [ 43598.203 ]
#  [ 33748.008 ]
#  [ 36609.203 ]
#  [ 32410.943 ]
#  [ 41656.375 ]
#  [ 32496.72  ]
#  [ 42206.734 ]
#  [ 34370.22  ]
#  [ 33277.69  ]
#  [ 40821.    ]
#  [ 40332.945 ]
#  [ 40677.72  ]
#  [ 37630.15  ]
#  [ 48243.855 ]
#  [ 42451.652 ]
#  [ 39558.88  ]
#  [ 46107.38  ]
#  [ 45401.43  ]
#  [ 48970.453 ]
#  [ 49874.996 ]
#  [ 55433.79  ]
#  [ 54154.617 ]
#  [ 57005.832 ]
#  [ 51948.44  ]
#  [ 52098.582 ]
#  [ 39424.754 ]
#  [ 45076.227 ]
#  [ 35844.48  ]
#  [ 39100.418 ]
#  [ 40840.258 ]
#  [ 36582.527 ]
#  [ 39600.08  ]
#  [ 39046.773 ]
#  [ 39082.934 ]
#  [ 31811.178 ]
#  [ 32852.78  ]
#  [ 26845.395 ]
#  [ 37689.81  ]
#  [ 34538.797 ]
#  [ 39624.227 ]
#  [ 35482.59  ]
#  [ 34453.918 ]
#  [ 35553.53  ]
#  [ 40420.54  ]
#  [ 42719.133 ]
#  [ 40223.89  ]
#  [ 36729.117 ]
#  [ 42763.383 ]
#  [ 47734.766 ]
#  [ 50856.07  ]
#  [ 45010.535 ]
#  [ 42302.477 ]
#  [ 50997.125 ]
#  [ 40833.918 ]
#  [ 43540.645 ]
#  [ 53932.75  ]
#  [ 45015.684 ]
#  [ 45095.117 ]
#  [ 41881.035 ]
#  [ 46460.766 ]
#  [ 52091.707 ]
#  [ 44990.773 ]
#  [ 41251.75  ]
#  [ 43825.082 ]
#  [ 51133.977 ]
#  [ 59126.586 ]
#  [ 45549.4   ]
#  [ 46806.28  ]
#  [ 49861.113 ]
#  [ 53134.73  ]
#  [ 65519.53  ]
#  [ 49944.37  ]
#  [ 57659.73  ]
#  [ 50104.51  ]
#  [ 58248.914 ]
#  [ 79292.19  ]
#  [ 77631.336 ]
#  [ 83060.305 ]
#  [ 76752.32  ]
#  [ 80643.04  ]
#  [ 85606.586 ]
#  [ 98878.4   ]
#  [132057.94  ]
#  [122758.26  ]
#  [110640.25  ]
#  [123870.14  ]
#  [123210.77  ]
#  [125535.07  ]
#  [166363.33  ]
#  [180829.7   ]
#  [173522.7   ]
#  [175719.92  ]
#  [176082.23  ]
#  [168054.73  ]
#  [203986.5   ]
#  [163526.03  ]
#  [184448.42  ]
#  [195917.55  ]
#  [181732.34  ]
#  [113795.69  ]
#  [ 79595.82  ]
#  [116649.586 ]
#  [ 96542.7   ]
#  [131440.62  ]
#  [105739.79  ]
#  [ 72251.36  ]]

# %%
# Merge the predicted data with the data set

n_steps=14
df_pred=pd.DataFrame.from_records(y_hat, columns=['Predicted'])
df_pred=df_pred.reset_index(drop=True)


df_actual= pd.DataFrame(dat[n_steps:len(dat)], columns=['Actual'])
df_actual=df_actual.reset_index(drop=True)


Date=df.iloc[n_steps:,0]
Date=Date.reset_index(drop=True)

data=pd.concat ([Date,df_actual,df_pred],axis=1)

print(data)
# Out:
#      Actual
# 0      2193
# 1      2027
# 2      1926
# 3      1979
# 4     -2364
# ..      ...
# 243  129544
# 244  105679
# 245   98578
# 246   80725
# 247   70160
#
# [248 rows x 1 columns]
# <class 'pandas.core.frame.DataFrame'>
# (248, 3)
#      Days  Actual      Predicted
# 0      15    2193    2248.331055
# 1      16    2027    2173.668213
# 2      17    1926    2240.063965
# 3      18    1979    2072.665283
# 4      19   -2364    2012.062378
# ..    ...     ...            ...
# 243   258  129544  116649.585938
# 244   259  105679   96542.703125
# 245   260   98578  131440.625000
# 246   261   80725  105739.789062
# 247   262   70160   72251.359375
#
# [248 rows x 3 columns]

# %% [markdown]
# **Evaluation Metrics for traning data set.**

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

R2=r2_score(df_actual, df_pred)
print('R Squared: ', R2)

mae=mean_absolute_error(df_actual, df_pred)
print('Mean Absolute Error: ', mae)

mse=mean_squared_error(df_actual, df_pred)
print('Mean Squared Error: ', mse)
# Out:
# R Squared:  0.9258081028158568
# Mean Absolute Error:  6410.925453432144
# Mean Squared Error:  113962674.37004818

# %%
# Plot the observed and predicted cases

fig, ax = plt.subplots(figsize=(9, 7))
ax.plot(data.index.values, data['Actual'])
data.Predicted.plot(ax=ax)
ax.set(xlabel="Date",
       ylabel="Cofirmed cases per day",
       title="Covid19 Cases")
plt.legend()
plt.show()

# %%
import datetime
from datetime import datetime, timedelta, date
last_date=df.iloc[-1,0]

predictions=model.predict(X,verbose=1)

# Length of future day you wanted to predict
future_time_steps=30
x1=X[-1:,:,:,:] # Last input
x1=x1.astype('float64')

p1=predictions[-1:]  # take last output

for i  in range(future_time_steps):
  #x2=np.array([[x1[0][0][1][0], x1[0][1][0][0], x1[0][1][1][0], x1[0][2][0][0], x1[0][2][1][0], x1[0][3][0][0], 
  #    x1[0][3][1][0], x1[0][4][0][0], x1[0][4][1][0], x1[0][5][0][0], x1[0][5][1][0], p1]] ,dtype=np.float)
  x2=np.array([[x1[0][0][1][0], x1[0][1][0][0], x1[0][1][1][0], x1[0][2][0][0], x1[0][2][1][0], x1[0][3][0][0], x1[0][3][1][0],
       x1[0][4][0][0], x1[0][4][1][0], x1[0][5][0][0], x1[0][5][1][0], x1[0][6][0][0], x1[0][6][1][0], p1]] ,dtype=np.float)
  
  
  print('X2 is', x2)
  x3=x2.reshape((1,7,2,1))

  p2=model.predict(x3, verbose=1)
  predictions=np.append(predictions, p2)
  x1=x3
  p1=p2

yhat=predictions
yhat=np.reshape(yhat, (-1,1))

df_pred=pd.DataFrame.from_records(yhat, columns=['Predicted'])
df_pred=df_pred.reset_index(drop=True)

df_actual=df[n_steps:len(df)]
df_actual=df_actual.reset_index(drop=True)
# Out:
# 8/8 [==============================] - 0s 45ms/step
# X2 is [[156384.       218705.       194747.       179731.       178163.
#   140566.       141398.       142122.       115280.       129544.
#   105679.        98578.        80725.        72251.359375]]
# 1/1 [==============================] - 0s 337ms/step
# X2 is [[218705.        194747.        179731.        178163.
#   140566.        141398.        142122.        115280.
#   129544.        105679.         98578.         80725.
#    72251.359375   70905.7421875]]
# 1/1 [==============================] - 0s 24ms/step
# X2 is [[194747.        179731.        178163.        140566.
#   141398.        142122.        115280.        129544.
#   105679.         98578.         80725.         72251.359375
#    70905.7421875  51769.6875   ]]
# 1/1 [==============================] - 0s 22ms/step
# X2 is [[179731.        178163.        140566.        141398.
#   142122.        115280.        129544.        105679.
#    98578.         80725.         72251.359375   70905.7421875
#    51769.6875     65976.0078125]]
# 1/1 [==============================] - 0s 21ms/step
# X2 is [[178163.        140566.        141398.        142122.
#   115280.        129544.        105679.         98578.
#    80725.         72251.359375   70905.7421875  51769.6875
#    65976.0078125  53684.8125   ]]
# 1/1 [==============================] - 0s 25ms/step
# X2 is [[140566.         141398.         142122.         115280.
#   129544.         105679.          98578.          80725.
#    72251.359375    70905.7421875   51769.6875      65976.0078125
#    53684.8125      34097.41796875]]
# 1/1 [==============================] - 0s 21ms/step
# X2 is [[141398.         142122.         115280.         129544.
#   105679.          98578.          80725.          72251.359375
#    70905.7421875   51769.6875      65976.0078125   53684.8125
#    34097.41796875  53527.390625  ]]
# 1/1 [==============================] - 0s 21ms/step
# X2 is [[142122.         115280.         129544.         105679.
#    98578.          80725.          72251.359375    70905.7421875
#    51769.6875      65976.0078125   53684.8125      34097.41796875
#    53527.390625   113017.4375    ]]
# 1/1 [==============================] - 0s 22ms/step
# X2 is [
]
# 1/1 [==============================] - 0s 21ms/step
# X2 is [[34085.1875     66183.96875    37960.46875    46169.92578125
#   44944.15625    24388.08789062 13967.63476562 61350.66796875
#   67570.2578125  49097.0703125  53634.08984375 36385.52734375
#   59795.90625    48247.        ]]
# 1/1 [==============================] - 0s 21ms/step
# X2 is [[66183.96875    37960.46875    46169.92578125 44944.15625
#   24388.08789062 13967.63476562 61350.66796875 67570.2578125
#   49097.0703125  53634.08984375 36385.52734375 59795.90625
#   48247.         67647.4609375 ]]
# 1/1 [==============================] - 0s 23ms/step
# X2 is [[37960.46875    46169.92578125 44944.15625    24388.08789062
#   13967.63476562 61350.66796875 67570.2578125  49097.0703125
#   53634.08984375 36385.52734375 59795.90625    48247.
#   67647.4609375  62411.1015625 ]]
# 1/1 [==============================] - 0s 21ms/step
# X2 is [[46169.92578125 44944.15625    24388.08789062 13967.63476562
#   61350.66796875 67570.2578125  49097.0703125  53634.08984375
#   36385.52734375 59795.90625    48247.         67647.4609375
#   62411.1015625  69644.7734375 ]]
# 1/1 [==============================] - 0s 22ms/step
# X2 is [[44944.15625    24388.08789062 13967.63476562 61350.66796875
#   67570.2578125  49097.0703125  53634.08984375 36385.52734375
#   59795.90625    48247.         67647.4609375  62411.1015625
#   69644.7734375  65748.796875  ]]
# 1/1 [==============================] - 0s 24ms/step
# X2 is [[24388.08789062 13967.63476562 61350.66796875 67570.2578125
#   49097.0703125  53634.08984375 36385.52734375 59795.90625
#   48247.         67647.4609375  62411.1015625  69644.7734375
#   65748.796875   70053.546875  ]]
# 1/1 [==============================] - 0s 22ms/step
# X2 is [[13967.63476562 61350.66796875 67570.2578125  49097.0703125
#   53634.08984375 36385.52734375 59795.90625    48247.
#   67647.4609375  62411.1015625  69644.7734375  65748.796875
#   70053.546875   70791.0078125 ]]
# 1/1 [==============================] - 0s 25ms/step
# X2 is [[61350.66796875 67570.2578125  49097.0703125  53634.08984375
#   36385.52734375 59795.90625    48247.         67647.4609375
#   62411.1015625  69644.7734375  65748.796875   70053.546875
#   70791.0078125  56930.84765625]]
# 1/1 [==============================] - 0s 22ms/step

# %%
# Concatinate the predicted data with observed data

Predicted_data=pd.concat ([df_actual,df_pred],axis=1)

print(type(Predicted_data))
print(Predicted_data.shape)
print(Predicted_data)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (278, 5)
#      Days       Date  Confirmed  Cumulative_cases     Predicted
# 0    15.0 2021-05-15     2193.0         4446828.0   2248.331055
# 1    16.0 2021-05-16     2027.0         4448855.0   2173.668213
# 2    17.0 2021-05-17     1926.0         4450781.0   2240.063965
# 3    18.0 2021-05-18     1979.0         4452760.0   2072.665283
# 4    19.0 2021-05-19    -2364.0         4450396.0   2012.062378
# ..    ...        ...        ...               ...           ...
# 273   NaN        NaT        NaN               NaN  65748.796875
# 274   NaN        NaT        NaN               NaN  70053.546875
# 275   NaN        NaT        NaN               NaN  70791.007812
# 276   NaN        NaT        NaN               NaN  56930.847656
# 277   NaN        NaT        NaN               NaN  62351.980469
#
# [278 rows x 5 columns]

# %% [markdown]
# ## Step 7: Download the data
#
# Write the Predicted data as .csv file and download it  for future purpose

# %%
from google.colab import files
Predicted_data.to_csv('UK -COVID-19 Prediction -CNN LSTM 22Jan22.csv') 
files.download('UK -COVID-19 Prediction -CNN LSTM 22Jan22.csv')
